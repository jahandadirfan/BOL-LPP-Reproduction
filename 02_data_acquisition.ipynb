# %% [markdown]
# <a href="https://colab.research.google.com/github/jahandadirfan/BOL-LPP-Reproduction/blob/main/02_data_acquisition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jahandadirfan/BOL-LPP-Reproduction.git
# Out:
# Cloning into 'BOL-LPP-Reproduction'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 41 (delta 15), reused 15 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 14.20 KiB | 3.55 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
