# %% [markdown]
# <a href="https://colab.research.google.com/github/jahandadirfan/BOL-LPP-Reproduction/blob/main/01_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BOL-LPP Reproduction Project
#
# ## Environment Setup
#
# This notebook verifies the Python and machine learning environment used for reproducing the BOL-LPP electricity price forecasting research.

# %%
import torch
print('PyTorch Version: ', torch.__version__)
print('Cuda available: ', torch.cuda.is_available())
if torch.cuda.is_available():
    print('Cuda device name: ', torch.cuda.get_device_name(0))
# Out:
# PyTorch Version:  2.11.0+cu128
# Cuda available:  True
# Cuda device name:  Tesla T4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# NumPy: 2.1.3
# Pandas: 2.2.3
# Scikit-learn: 1.6.1

# %%
# !pip install optuna

# %%
import optuna

print("Optuna:", optuna.__version__)
# Out:
# Optuna: 4.9.0

# %%
# !git clone https://github.com/jahandadirfan/BOL-LPP-Reproduction.git
# Out:
# Cloning into 'BOL-LPP-Reproduction'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 21 (delta 5), reused 19 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 6.21 KiB | 6.21 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !ls
# Out:
# BOL-LPP-Reproduction  drive

# %%
# %cd BOL-LPP-Reproduction
# Out:
# /content/BOL-LPP-Reproduction

# %%
# !ls
# Out:
# notebooks  README.md  results  src

# %%
# !pwd
# Out:
# /content/BOL-LPP-Reproduction

# %%
# !ls
# Out:
# notebooks  README.md  results  src

# %%
# %cd ..
# Out:
# /content

# %%
# !rm -rf /content/sample_data

# %%
# !ls
# Out:
# BOL-LPP-Reproduction  drive
